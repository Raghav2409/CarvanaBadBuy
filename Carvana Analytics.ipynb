# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('/Users/raghav/Downloads/DontGetKicked/training.csv')
data.head()
# Out:
#    RefId  IsBadBuy  PurchDate Auction  VehYear  VehicleAge   Make  \
# 0      1         0  12/7/2009   ADESA     2006           3  MAZDA
# 1      2         0  12/7/2009   ADESA     2004           5  DODGE
# 2      3         0  12/7/2009   ADESA     2005           4  DODGE
# 3      4         0  12/7/2009   ADESA     2004           5  DODGE
# 4      5         0  12/7/2009   ADESA     2005           4   FORD
#
#                  Model Trim           SubModel  ...  \
# 0               MAZDA3    i         4D SEDAN I  ...
# 1  1500 RAM PICKUP 2WD   ST  QUAD CAB 4.7L SLT  ...
# 2           STRATUS V6  SXT   4D SEDAN SXT FFV  ...
# 3                 NEON  SXT           4D SEDAN  ...
# 4                FOCUS  ZX3       2D COUPE ZX3  ...
#
#   MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT AUCGUART  \
# 0                      11597.0                    12409.0        NaN      NaN
# 1                      11374.0                    12791.0        NaN      NaN
# ...

# %%
data.describe()
# Out:
#               RefId      IsBadBuy       VehYear    VehicleAge   WheelTypeID  \
# count  72983.000000  72983.000000  72983.000000  72983.000000  69814.000000
# mean   36511.428497      0.122988   2005.343052      4.176644      1.494299
# std    21077.241302      0.328425      1.731252      1.712210      0.521290
# min        1.000000      0.000000   2001.000000      0.000000      0.000000
# 25%    18257.500000      0.000000   2004.000000      3.000000      1.000000
# 50%    36514.000000      0.000000   2005.000000      4.000000      1.000000
# 75%    54764.500000      0.000000   2007.000000      5.000000      2.000000
# max    73014.000000      1.000000   2010.000000      9.000000      3.000000
#
#               VehOdo  MMRAcquisitionAuctionAveragePrice  \
# count   72983.000000                       72965.000000
# mean    71499.995917                        6128.909217
# std     14578.913128                        2461.992768
# min      4825.000000                           0.000000
# ...

# %%
#Make Vs 'IsBadBuy'
grouped_data = data.groupby('Make')['IsBadBuy'].mean() * 100

#bar plot
fig, ax = plt.subplots(figsize=(50,10))
ax.bar(grouped_data.index, grouped_data)

#Labels
ax.set_xlabel('Make')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by Make')

plt.show()

# %%
#Trim vs IsBadBuy
grouped_data1 = data.groupby('Trim')['IsBadBuy'].mean() * 100

#bar plot
fig, ax = plt.subplots(figsize=(55,10))
ax.bar(grouped_data1.index, grouped_data1)

#Labels
ax.set_xlabel('Trim')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by Trim')

plt.show()

# %%
#VNST (State) vs IsBadBuy
grouped_data2 = data.groupby('VNST')['IsBadBuy'].mean() * 100

#bar plot
fig, ax = plt.subplots(figsize=(50,6))
ax.bar(grouped_data2.index, grouped_data2)

#Labels
ax.set_xlabel('VNST')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by VNST')

plt.show()

# %%
#Auction vs IsBadBuy
grouped_data3 = data.groupby('Auction')['IsBadBuy'].mean() * 100

#Line chart
fig, ax = plt.subplots(figsize=(30,6))
ax.plot(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('Auction')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by Auction')

plt.show()

# %%
#Transmission vs IsBadBuy
grouped_data3 = data.groupby('Transmission')['IsBadBuy'].mean() * 100

#Line chart
fig, ax = plt.subplots(figsize=(30,6))
ax.plot(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('Transmission')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by Transmission')

plt.show()

# %%
#WheelType vs IsBadBuy
grouped_data3 = data.groupby('WheelType')['IsBadBuy'].mean() * 100

#Line chart
fig, ax = plt.subplots(figsize=(30,6))
ax.plot(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('WheelType')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by Wheeltype')

plt.show()

# %%
#Nationality vs IsBadBuy
grouped_data3 = data.groupby('Nationality')['IsBadBuy'].mean() * 100

#Line chart
fig, ax = plt.subplots(figsize=(30,6))
ax.plot(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('Nationality')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by Nationality')

plt.show()

# %%
#TopThreeAmericanName vs IsBadBuy
grouped_data3 = data.groupby('TopThreeAmericanName')['IsBadBuy'].mean() * 100

#Line chart
fig, ax = plt.subplots(figsize=(30,6))
ax.plot(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('TopThreeAmericanName')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by TopThreeAmericanName')

plt.show()

# %%
#VehYear vs IsBadBuy
grouped_data3 = data.groupby('VehYear')['IsBadBuy'].mean() * 100

#bar plot
fig, ax = plt.subplots(figsize=(30,6))
ax.bar(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('VehYear')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by VehYear')

plt.show()

# %%
#VehAge Vs IsBadBuy
grouped_data3 = data.groupby('VehicleAge')['IsBadBuy'].mean() * 100

#bar plot
fig, ax = plt.subplots(figsize=(30,6))
ax.bar(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('VehicleAge')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by VehicleAge')

plt.show()

# %%
#WheelTypeID Vs IsBadBuy
grouped_data3 = data.groupby('WheelTypeID')['IsBadBuy'].mean() * 100

#bar plot
fig, ax = plt.subplots(figsize=(30,6))
ax.bar(grouped_data3.index, grouped_data3)

#Labels
ax.set_xlabel('WheelTypeID')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by WheelTypeID')

plt.show()

# %%
#IsOnlineSale vs IsBadBuy
count_data = data.groupby(['IsOnlineSale', 'IsBadBuy']).size().unstack()

#Stacked Bar Plot
count_data.plot(kind='bar', stacked=True)

#Labels
plt.xlabel('IsOnlineSale')
plt.ylabel('Count')
plt.title('Relationship between IsOnlineSale and IsBadBuy')

plt.show()

# %%
#Vehicle Odometer reading Vs IsBadBuy
dataForPlot = [list(data[data.IsBadBuy==0].VehOdo), list(data[data.IsBadBuy==1].VehOdo)]
fig, ax = plt.subplots()
ax.boxplot(dataForPlot)
ax.set_xticks([1, 2])
ax.set_xticklabels([0, 1])
ax.set_xlabel('IsBadBuy')
ax.set_ylabel('VehOdo')
plt.show()

# %%
#VehBCost Vs IsBadBuy
dataForPlot = [list(data[data.IsBadBuy==0].VehBCost), list(data[data.IsBadBuy==1].VehBCost)]
fig, ax = plt.subplots()
ax.boxplot(dataForPlot)
ax.set_xticks([1, 2])
ax.set_xticklabels([0, 1])
ax.set_xlabel('IsBadBuy')
ax.set_ylabel('VehBCost')
plt.show()

# %%
#Warranty Cost Vs IsBadBuy
dataForPlot = [list(data[data.IsBadBuy==0].WarrantyCost), list(data[data.IsBadBuy==1].WarrantyCost)]
fig, ax = plt.subplots()
ax.boxplot(dataForPlot)
ax.set_xticks([1, 2])
ax.set_xticklabels([0, 1])
ax.set_xlabel('IsBadBuy')
ax.set_ylabel('WarrantyCost')
plt.show()

# %%
#'MMRAcquisitionAuctionAveragePrice', 'MMRAcquisitionAuctionCleanPrice', 'MMRAcquisitionRetailAveragePrice', 'MMRAcquisitonRetailCleanPrice' Vs IsBadBuy

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))

# regular scale
ax = data.boxplot(column='MMRAcquisitionAuctionAveragePrice', by='IsBadBuy', ax=axes[0][0])
ax.set_ylabel('MMRAcquisitionAuctionAveragePrice')
ax.set_xlabel('IsBadBuy')


ax = data.boxplot(column='MMRAcquisitionAuctionCleanPrice', by='IsBadBuy', ax=axes[0][1])
ax.set_ylabel('MMRAcquisitionAuctionCleanPrice')
ax.set_xlabel('IsBadBuy')

ax = data.boxplot(column='MMRAcquisitionRetailAveragePrice', by='IsBadBuy', ax=axes[1][0])
ax.set_ylabel('MMRAcquisitionRetailAveragePrice')
ax.set_xlabel('IsBadBuy')

ax = data.boxplot(column='MMRAcquisitonRetailCleanPrice', by='IsBadBuy', ax=axes[1][1])
ax.set_ylabel('MMRAcquisitonRetailCleanPrice')
ax.set_xlabel('IsBadBuy')


# suppress the title
#axes[0].get_figure().suptitle('')
plt.tight_layout()

plt.show()

# %%
#'MMRCurrentAuctionAveragePrice', 'MMRCurrentAuctionCleanPrice', 'MMRCurrentRetailAveragePrice', 'MMRCurrentRetailCleanPrice' Vs IsBadBuy
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))

# regular scale
ax = data.boxplot(column='MMRCurrentAuctionAveragePrice', by='IsBadBuy', ax=axes[0][0])
ax.set_ylabel('MMRCurrentAuctionAveragePrice')
ax.set_xlabel('IsBadBuy')

ax = data.boxplot(column='MMRCurrentAuctionCleanPrice', by='IsBadBuy', ax=axes[0][1])
ax.set_ylabel('MMRCurrentAuctionCleanPrice')
ax.set_xlabel('IsBadBuy')

ax = data.boxplot(column='MMRCurrentRetailAveragePrice', by='IsBadBuy', ax=axes[1][0])
ax.set_ylabel('MMRCurrentRetailAveragePrice')
ax.set_xlabel('IsBadBuy')

ax = data.boxplot(column='MMRCurrentRetailCleanPrice', by='IsBadBuy', ax=axes[1][1])
ax.set_ylabel('MMRCurrentRetailCleanPrice')
ax.set_xlabel('IsBadBuy')


# suppress the title
#axes[0].get_figure().suptitle('')
plt.tight_layout()

plt.show()

# %%
#Profit/Loss Vs IsBadBuy
profitloss = data['MMRCurrentRetailCleanPrice'] - data['MMRAcquisitonRetailCleanPrice']
data['profitloss'] = profitloss

grouped_data3 = data.groupby('IsBadBuy')['profitloss'].mean() * 100

# Create a bar plot
fig, ax = plt.subplots(figsize=(30,6))
ax.plot(grouped_data3.index, grouped_data3)

# Label the plot
ax.set_xlabel('VNST')
ax.set_ylabel('Mean IsBadBuy Percentage')
ax.set_title('Mean IsBadBuy Percentage by Transmission')

# Show the plot
plt.show()
